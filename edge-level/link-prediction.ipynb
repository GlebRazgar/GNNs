# %% [markdown]
# # Edge-level tasks:
# 1. Link Prediction (Most Common)
# - Social Networks: Predicting if two users will follow each other    friends
# - Weather forecasting: Predicting how strongly Station A's weather affects Station B (influence / correlation strength prediction)
# - Wind/Weather Front Direction ("During a storm, coastal stations have stronger influence on inland stations")
#
# Social Networks: Predicting if two users will become friends
# 1. Edge Classification
# Predicting bond types (single, double, triple)
